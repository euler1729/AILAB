# %%
# !pip install wheel setuptools pip --upgrade
# Out:
# Requirement already satisfied: wheel in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (0.43.0)
# Requirement already satisfied: setuptools in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (69.5.1)
# Requirement already satisfied: pip in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (24.0)

# %%
# !pip install swig
# !pip install gymnasium
# !pip install 'gymnasium[all]'
# !pip install 'gymnasium[box2d]'
# Out:
# Requirement already satisfied: swig in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (4.2.1)
# Requirement already satisfied: gymnasium in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from gymnasium) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: gymnasium[all] in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from gymnasium[all]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from gymnasium[all]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from gymnasium[all]) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from gymnasium[all]) (0.0.4)
# Collecting shimmy<1.0,>=0.1.0 (from shimmy[atari]<1.0,>=0.1.0; extra == "all"->gymnasium[all])
#   Using cached Shimmy-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting box2d-py==2.3.5 (from gymnasium[all])
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pygame>=2.1.3 (from gymnasium[all])
#   Using cached pygame-2.5.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: swig==4.* in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from gymnasium[all]) (4.2.1)
# Collecting mujoco-py<2.2,>=2.1 (from gymnasium[all])
#   Using cached mujoco_py-2.1.2.14-py3-none-any.whl.metadata (669 bytes)
# Collecting cython<3 (from gymnasium[all])
#   Using cached Cython-0.29.37-py2.py3-none-any.whl.metadata (3.1 kB)
# Collecting mujoco>=2.3.3 (from gymnasium[all])
#   Using cached mujoco-3.1.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (44 kB)
# Collecting imageio>=2.14.1 (from gymnasium[all])
#   Using cached imageio-2.34.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting jax>=0.4.0 (from gymnasium[all])
#   Using cached jax-0.4.26-py3-none-any.whl.metadata (23 kB)
# Collecting jaxlib>=0.4.0 (from gymnasium[all])
#   Using cached jaxlib-0.4.26-cp311-cp311-macosx_11_0_arm64.whl.metadata (1.8 kB)
# Collecting lz4>=3.1.0 (from gymnasium[all])
#   Using cached lz4-4.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.7 kB)
# Collecting opencv-python>=3.0 (from gymnasium[all])
#   Using cached opencv_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting matplotlib>=3.0 (from gymnasium[all])
#   Using cached matplotlib-3.8.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting moviepy>=1.0.0 (from gymnasium[all])
#   Using cached moviepy-1.0.3-py3-none-any.whl
# Requirement already satisfied: torch>=1.0.0 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from gymnasium[all]) (2.2.2)
# Collecting pillow>=8.3.2 (from imageio>=2.14.1->gymnasium[all])
#   Using cached pillow-10.3.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting ml-dtypes>=0.2.0 (from jax>=0.4.0->gymnasium[all])
#   Using cached ml_dtypes-0.4.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (20 kB)
# Collecting opt-einsum (from jax>=0.4.0->gymnasium[all])
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting scipy>=1.9 (from jax>=0.4.0->gymnasium[all])
#   Using cached scipy-1.13.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (60 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.0->gymnasium[all])
#   Using cached contourpy-1.2.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.0->gymnasium[all])
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.0->gymnasium[all])
#   Using cached fonttools-4.51.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (159 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.0->gymnasium[all])
#   Using cached kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[all]) (24.0)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.0->gymnasium[all])
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from matplotlib>=3.0->gymnasium[all]) (2.9.0.post0)
# Collecting decorator<5.0,>=4.0.2 (from moviepy>=1.0.0->gymnasium[all])
#   Using cached decorator-4.4.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from moviepy>=1.0.0->gymnasium[all]) (4.66.2)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from moviepy>=1.0.0->gymnasium[all]) (2.31.0)
# Collecting proglog<=1.0.0 (from moviepy>=1.0.0->gymnasium[all])
#   Using cached proglog-0.1.10-py3-none-any.whl.metadata (639 bytes)
# Collecting imageio-ffmpeg>=0.2.0 (from moviepy>=1.0.0->gymnasium[all])
#   Using cached imageio_ffmpeg-0.4.9-py3-none-any.whl
# Collecting absl-py (from mujoco>=2.3.3->gymnasium[all])
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting etils[epath] (from mujoco>=2.3.3->gymnasium[all])
#   Using cached etils-1.8.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting glfw (from mujoco>=2.3.3->gymnasium[all])
#   Using cached glfw-2.7.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting pyopengl (from mujoco>=2.3.3->gymnasium[all])
#   Using cached PyOpenGL-3.1.7-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: cffi>=1.10 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from mujoco-py<2.2,>=2.1->gymnasium[all]) (1.16.0)
# Collecting fasteners~=0.15 (from mujoco-py<2.2,>=2.1->gymnasium[all])
#   Using cached fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Collecting ale-py~=0.8.1 (from shimmy[atari]<1.0,>=0.1.0; extra == "all"->gymnasium[all])
#   Using cached ale_py-0.8.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Requirement already satisfied: filelock in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch>=1.0.0->gymnasium[all]) (3.13.3)
# Requirement already satisfied: sympy in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch>=1.0.0->gymnasium[all]) (1.12)
# Requirement already satisfied: networkx in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch>=1.0.0->gymnasium[all]) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch>=1.0.0->gymnasium[all]) (3.1.3)
# Requirement already satisfied: fsspec in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch>=1.0.0->gymnasium[all]) (2024.2.0)
# Collecting importlib-resources (from ale-py~=0.8.1->shimmy[atari]<1.0,>=0.1.0; extra == "all"->gymnasium[all])
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pycparser in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from cffi>=1.10->mujoco-py<2.2,>=2.1->gymnasium[all]) (2.22)
# Requirement already satisfied: setuptools in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from imageio-ffmpeg>=0.2.0->moviepy>=1.0.0->gymnasium[all]) (69.5.1)
# Requirement already satisfied: six>=1.5 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[all]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gymnasium[all]) (2024.2.2)
# Collecting zipp (from etils[epath]->mujoco>=2.3.3->gymnasium[all])
#   Using cached zipp-3.18.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from jinja2->torch>=1.0.0->gymnasium[all]) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from sympy->torch>=1.0.0->gymnasium[all]) (1.3.0)
# Using cached Cython-0.29.37-py2.py3-none-any.whl (989 kB)
# Using cached imageio-2.34.1-py3-none-any.whl (313 kB)
# Using cached jax-0.4.26-py3-none-any.whl (1.9 MB)
# Using cached jaxlib-0.4.26-cp311-cp311-macosx_11_0_arm64.whl (66.7 MB)
# Using cached lz4-4.3.3-cp311-cp311-macosx_11_0_arm64.whl (212 kB)
# Using cached matplotlib-3.8.4-cp311-cp311-macosx_11_0_arm64.whl (7.5 MB)
# Using cached mujoco-3.1.4-cp311-cp311-macosx_11_0_arm64.whl (5.4 MB)
# Using cached mujoco_py-2.1.2.14-py3-none-any.whl (2.4 MB)
# Using cached opencv_python-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl (35.4 MB)
# Using cached pygame-2.5.2-cp311-cp311-macosx_11_0_arm64.whl (12.2 MB)
# Using cached Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Using cached ale_py-0.8.1-cp311-cp311-macosx_11_0_arm64.whl (1.0 MB)
# Using cached contourpy-1.2.1-cp311-cp311-macosx_11_0_arm64.whl (245 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Using cached fasteners-0.19-py3-none-any.whl (18 kB)
# Using cached fonttools-4.51.0-cp311-cp311-macosx_10_9_universal2.whl (2.8 MB)
# Using cached glfw-2.7.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-macosx_11_0_arm64.whl (94 kB)
# Using cached kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl (66 kB)
# Using cached ml_dtypes-0.4.0-cp311-cp311-macosx_10_9_universal2.whl (390 kB)
# Using cached pillow-10.3.0-cp311-cp311-macosx_11_0_arm64.whl (3.4 MB)
# Using cached proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached scipy-1.13.0-cp311-cp311-macosx_12_0_arm64.whl (30.3 MB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Using cached PyOpenGL-3.1.7-py3-none-any.whl (2.4 MB)
# Using cached etils-1.8.0-py3-none-any.whl (156 kB)
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Using cached zipp-3.18.1-py3-none-any.whl (8.2 kB)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp311-cp311-macosx_14_0_arm64.whl size=435145 sha256=c98c8f0253d7c144639d56226e280c8aa6e7cbeaee4f9134103060ad42c5275b
#   Stored in directory: /Users/mahmud/Library/Caches/pip/wheels/ab/f1/0c/d56f4a2bdd12bae0a0693ec33f2f0daadb5eb9753c78fa5308
# Successfully built box2d-py
# Installing collected packages: pyopengl, glfw, box2d-py, zipp, scipy, pyparsing, pygame, proglog, pillow, opt-einsum, opencv-python, ml-dtypes, lz4, kiwisolver, importlib-resources, imageio-ffmpeg, fonttools, fasteners, etils, decorator, cython, cycler, contourpy, absl-py, shimmy, matplotlib, jaxlib, jax, imageio, ale-py, mujoco-py, moviepy, mujoco
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
# Successfully installed absl-py-2.1.0 ale-py-0.8.1 box2d-py-2.3.5 contourpy-1.2.1 cycler-0.12.1 cython-0.29.37 decorator-4.4.2 etils-1.8.0 fasteners-0.19 fonttools-4.51.0 glfw-2.7.0 imageio-2.34.1 imageio-ffmpeg-0.4.9 importlib-resources-6.4.0 jax-0.4.26 jaxlib-0.4.26 kiwisolver-1.4.5 lz4-4.3.3 matplotlib-3.8.4 ml-dtypes-0.4.0 moviepy-1.0.3 mujoco-3.1.4 mujoco-py-2.1.2.14 opencv-python-4.9.0.80 opt-einsum-3.3.0 pillow-10.3.0 proglog-0.1.10 pygame-2.5.2 pyopengl-3.1.7 pyparsing-3.1.2 scipy-1.13.0 shimmy-0.2.1 zipp-3.18.1
# Requirement already satisfied: gymnasium[box2d] in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from gymnasium[box2d]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from gymnasium[box2d]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from gymnasium[box2d]) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from gymnasium[box2d]) (2.5.2)
# Requirement already satisfied: swig==4.* in /Users/mahmud/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from gymnasium[box2d]) (4.2.1)

# %%
# %matplotlib inline

# %%
import gymnasium as gym
env = gym.make("LunarLander-v2", render_mode="human")
observation, info = env.reset()

for _ in range(5000):
    action = env.action_space.sample()  # agent policy that uses the observation and info
    observation, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
        observation, info = env.reset()

env.close()
